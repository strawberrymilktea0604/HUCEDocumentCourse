# %%
from sympy import *

# %%
factorint(980_220)
# Out:
# {2: 2, 3: 1, 5: 1, 17: 1, 31: 2}

# %%
n = 998220
i = 2
res = {}
while n != 1:
    while n % i != 0:
        i += 1
    res[i] = 0
    while n % i == 0:
        n = n // i
        res[i] += 1
res
# Out:
# {2: 2, 3: 1, 5: 1, 127: 1, 131: 1}
