# %%
#tim so nguyen to
def check_prime(n):
    for k in range(2, n):
        if n % k ==0:
            a = 0
            return 0
    return 1

# %%
check_prime(103)
# Out:
# 1

# %%
def ucln(a, b):
    if(b == 0):
        return a
    return ucln(b, a % b)

# %%
ucln(12, 18)
# Out:
# 6

# %%
a0 = 2025

# %%
a = 8928
b = 2025
n = 10
while(b != 0):
    r = a % b
    a = b
    b = r   
    print(a)
# Out:
# 2025
# 828
# 369
# 90
# 9
