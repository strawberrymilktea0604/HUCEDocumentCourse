# %%
def hoan_vi(a):
    n = len(a)
    if n == 1:
        return [a]
    C = []
    for i in range(n):
        b = a.copy()
        x = b.pop(i)
        for p in hoan_vi(b):
            p = [x] + p
            C.append(p)
    
    return C

# %%
for i in hoan_vi([1, 2, 3, 4, 5, 6]):
    if(i[0] == 1 and i[1] == 4):
        print(i)
# Out:
# [1, 4, 2, 3, 5, 6]
# [1, 4, 2, 3, 6, 5]
# [1, 4, 2, 5, 3, 6]
# [1, 4, 2, 5, 6, 3]
# [1, 4, 2, 6, 3, 5]
# [1, 4, 2, 6, 5, 3]
# [1, 4, 3, 2, 5, 6]
# [1, 4, 3, 2, 6, 5]
# [1, 4, 3, 5, 2, 6]
# [1, 4, 3, 5, 6, 2]
# [1, 4, 3, 6, 2, 5]
# [1, 4, 3, 6, 5, 2]
# [1, 4, 5, 2, 3, 6]
# [1, 4, 5, 2, 6, 3]
# [1, 4, 5, 3, 2, 6]
# [1, 4, 5, 3, 6, 2]
# [1, 4, 5, 6, 2, 3]
# [1, 4, 5, 6, 3, 2]
# [1, 4, 6, 2, 3, 5]
# [1, 4, 6, 2, 5, 3]
# [1, 4, 6, 3, 2, 5]
# [1, 4, 6, 3, 5, 2]
# [1, 4, 6, 5, 2, 3]
# [1, 4, 6, 5, 3, 2]

# %%
#tinh so hoan vi = n!
from sympy import *
factorial(7)
# Out:
# 5040
