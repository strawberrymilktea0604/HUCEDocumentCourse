# %%
class Per:
    ten = "Ho Van Ten"
A = Per()
B = Per()
A.ten, B.ten
# Out:
# ('Ho Van Ten', 'Ho Van Ten')

# %%
Per.ten = "Ho Van C"
A.ten, B.ten
# Out:
# ('Ho Van C', 'Ho Van C')

# %%
A.ten = "Ji Qui Ka"
A.ten, B.ten
# Out:
# ('Ji Qui Ka', 'Ho Van C')

# %%
Per.ten = "HHH"
A.ten, B.ten
# Out:
# ('Ji Qui Ka', 'HHH')

# %%
class Person:    
    def __init__(self, name, age, gender):
        self.name = name
        self.age = age
        self.gender = gender
a = Person('name', 10, True)

# %%
class AAA:
    chao = ""
J = AAA()
def hello():
    print("Chao xin")
J.chao = hello
# print("chao xong")
J.chao()
# Out:
# Chao xin

# %%
# from itertools import permutations
# txt = 'ầpởưthhngm'
# perms = [''.join(p) for p in permutations(txt)]

# for perm in perms:
#     print(perm)
